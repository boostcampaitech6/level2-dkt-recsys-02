# %% [markdown]
# # Simple Weighted Ensemble

# %%
import pandas as pd
import numpy as np

# %%
# submission csv 파일 불러오기

# mf = pd.read_csv("56_MF.csv")
# transformer = pd.read_csv("58_transformer.csv")
catboost = pd.read_csv("63_catboost.csv")
e = pd.read_csv("16+56+58+59.csv")
submit = pd.read_csv('sample_submission.csv')

# %%
mf.head()
# Out:
#    id  prediction
# 0   0    0.592135
# 1   1    0.789078
# 2   2    0.337941
# 3   3    0.732488
# 4   4    0.338837

# %%
transformer.head()
# Out:
#    id  prediction
# 0   0    0.536512
# 1   1    0.838237
# 2   2    0.244537
# 3   3    0.847905
# 4   4    0.274332

# %%
catboost.head()
# Out:
#    id  prediction
# 0   0    0.685023
# 1   1    0.857404
# 2   2    0.344687
# 3   3    0.831782
# 4   4    0.287020

# %%
lgcn.head()
# Out:
#    id  prediction
# 0   0    0.563862
# 1   1    0.797269
# 2   2    0.250936
# 3   3    0.728545
# 4   4    0.533288

# %%
# 확인사항 1) 앙상블하기 전 모든 데이터가 제대로 임포트 되었는데 확인합니다
# 확인사항 2) 모든 파일들의 index가 동일한 지 확인
# 확인사항 3) 모든 파일들의 컬럼 명 확인

# catboost1.head()
# catboost2.head()

# CNN_FM.head()

# CNN_DCN1.head()
# CNN_DCN2.head()

submit.head()
# Out:
#    id  prediction
# 0   0    0.616341
# 1   1    0.831545
# 2   2    0.306383
# 3   3    0.780467
# 4   4    0.338303

# %%
# 가중합 방식으로 simple_weighted_ensemble을 시행합니다

submit['prediction'] = 0.3 * catboost['prediction'] + 0.7 * e['prediction']

# %%
submit.to_csv('66.csv', index=False)

# %%
import matplotlib.pyplot as plt

# 데이터

# 히스토그램 그리기
plt.hist(submit['prediction'], bins=10, edgecolor='black', alpha = 0.5)  # 데이터와 구간 개수 설정
plt.hist(mf['prediction'], bins=10, edgecolor='black', alpha = 0.5)
# 그래프 제목과 축 제목 설정
plt.title("Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt

# 데이터

# 히스토그램 그리기
plt.hist(submit['prediction'], bins=10, edgecolor='black')  # 데이터와 구간 개수 설정

# 그래프 제목과 축 제목 설정
plt.title("Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt

# 데이터

# 히스토그램 그리기
plt.hist(lgcn['prediction'], bins=10, edgecolor='black')  # 데이터와 구간 개수 설정

# 그래프 제목과 축 제목 설정
plt.title("Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")

# 그래프 보여주기
plt.show()

# %%
import matplotlib.pyplot as plt

# 데이터

# 히스토그램 그리기
plt.hist(lgcn['prediction'], bins=10, edgecolor='black')  # 데이터와 구간 개수 설정

# 그래프 제목과 축 제목 설정
plt.title("Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")

# 그래프 보여주기
plt.show()
