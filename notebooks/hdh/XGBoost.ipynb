# %% [markdown]
# # XGBoost
#
# - [docs](https://xgboost.readthedocs.io/en/stable/#)

# %%
import pandas as pd
import numpy as np
import os
import random
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## 1. Data Load

# %%
data_dir = './data/'
csv_file_path = os.path.join(data_dir, 'train_data.csv') 
df = pd.read_csv(csv_file_path)
df.head()
# Out:
#    userID assessmentItemID      testId  answerCode            Timestamp  \
# 0       0       A060001001  A060000001           1  2020-03-24 00:17:11
# 1       0       A060001002  A060000001           1  2020-03-24 00:17:14
# 2       0       A060001003  A060000001           1  2020-03-24 00:17:22
# 3       0       A060001004  A060000001           1  2020-03-24 00:17:29
# 4       0       A060001005  A060000001           1  2020-03-24 00:17:36
#
#    KnowledgeTag
# 0          7224
# 1          7225
# 2          7225
# 3          7225
# 4          7225

# %% [markdown]
# ## 2. Feature Engineering

# %%
import pandas as pd

def feature_engineering(df):

    # 유저별로 정렬
    df.sort_values(by=['userID', 'Timestamp'], inplace=True)
    
    # 데이터 타입 변경
    dtype = {
        'userID': 'int16',
        'answerCode': 'int8',
        'KnowledgeTag': 'int16'
    }
    df = df.astype(dtype)
    
    # 'Timestamp' 열을 날짜/시간 형식으로 파싱
    df['Timestamp'] = pd.to_datetime(df['Timestamp'], format='%Y-%m-%d %H:%M:%S')

    # testTag 추가
    df['testTag'] = df['testId'].apply(lambda x: x[2]).astype('int16')

    # 유저별로 정답 누적 횟수 계산, 결측치 0
    df['user_correct_answer'] = df.groupby('userID')['answerCode'].transform(lambda x: x.cumsum().shift(1))
    df['user_correct_answer'].fillna(0, inplace=True)
    
    # 유저별로 제출 누적 횟수 계산
    df['user_total_answer'] = df.groupby('userID')['answerCode'].cumcount() 
    
    # 유저별로 누적 정답률 계산, 결측치 0.75
    df['user_acc'] = df['user_correct_answer'] / df['user_total_answer']
    df['user_acc'].fillna(0.75, inplace=True)

    # userID별 정답률 추가
    df['user_sum'] = df.groupby('userID')['answerCode'].transform('sum')
    df['user_mean'] = df.groupby('userID')['answerCode'].transform('mean')
    
    # assessmentItemID별 정답률 추가
    df['assessment_sum'] = df.groupby('assessmentItemID')['answerCode'].transform('sum')
    df['assessment_mean'] = df.groupby('assessmentItemID')['answerCode'].transform('mean')
    
    # testId별 정답률 추가
    df['test_sum'] = df.groupby('testId')['answerCode'].transform('sum')
    df['test_mean'] = df.groupby('testId')['answerCode'].transform('mean')
    
    # KnowledgeTag별 정답률 추가
    df['knowledgeTag_sum'] = df.groupby('KnowledgeTag')['answerCode'].transform('sum')
    df['knowledgeTag_mean'] = df.groupby('KnowledgeTag')['answerCode'].transform('mean')
    
    # testTag별 정답률 추가
    df['testTag_sum'] = df.groupby('testTag')['answerCode'].transform('sum')
    df['testTag_mean'] = df.groupby('testTag')['answerCode'].transform('mean')

    # 상대적 정답률
    df['relative_answer_assessment'] = df['answerCode'] - df.groupby('assessmentItemID')['answerCode'].transform('mean')
    
    # 유저별 상대적 정답률 평균 - 학습 수준 레벨
    df['relative_answer_mean'] = df.groupby('userID')['relative_answer_assessment'].transform('mean')

    # 유저가 문항을 푼 시간
    df['time_to_solve'] = df.groupby(['userID', 'testId'])['Timestamp'].diff().dt.total_seconds().shift(-1)
    
    # 결측치 이전 행의 값으로 채움
    df['time_to_solve'].fillna(method='ffill', inplace=True)

    # 유저별 문항 시간 평균
    #df['time_to_solve_mean'] = df.groupby('userID')['time_to_solve'].transform('mean')
    df['time_to_solve_mean'] = df.groupby(['userID', 'testId'])['time_to_solve'].transform('mean')

    # clip(0, 255)는 메모리를 위해 uint8 데이터 타입을 쓰기 위함
    df['prior_assessment_frequency'] = df.groupby(['userID', 'assessmentItemID']).cumcount().clip(0, 255)

    # 각 태그별로 이전에 몇번 풀었는지
    df['prior_KnowledgeTag_frequency'] = df.groupby(['userID', 'KnowledgeTag']).cumcount()
    
    # 시험지 태그별 학년별 몇번 풀었는지
    df['prior_testTag_frequency'] = df.groupby(['userID', 'testTag']).cumcount()
    
    return df

# %%
df = feature_engineering(df)
df.head()
# Out:
# /var/folders/8r/strv9f_x6b3ghnb0chcl145m0000gn/T/ipykernel_2741/21048499.py:63: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['time_to_solve'].fillna(method='ffill', inplace=True)
#    userID assessmentItemID      testId  answerCode           Timestamp  \
# 0       0       A060001001  A060000001           1 2020-03-24 00:17:11
# 1       0       A060001002  A060000001           1 2020-03-24 00:17:14
# 2       0       A060001003  A060000001           1 2020-03-24 00:17:22
# 3       0       A060001004  A060000001           1 2020-03-24 00:17:29
# 4       0       A060001005  A060000001           1 2020-03-24 00:17:36
#
#    KnowledgeTag  testTag  user_correct_answer  user_total_answer  user_acc  \
# 0          7224        6                  0.0                  0      0.75
# 1          7225        6                  1.0                  1      1.00
# 2          7225        6                  2.0                  2      1.00
# 3          7225        6                  3.0                  3      1.00
# 4          7225        6                  4.0                  4      1.00
#
#    ...  knowledgeTag_mean  testTag_sum  testTag_mean  \
# 0  ...           0.955022       187545      0.709232
# 1  ...           0.913187       187545      0.709232
# 2  ...           0.913187       187545      0.709232
# 3  ...           0.913187       187545      0.709232
# 4  ...           0.913187       187545      0.709232
#
#    relative_answer_assessment  relative_answer_mean  time_to_solve  \
# 0                    0.017937             -0.025899            3.0
# 1                    0.035874             -0.025899            8.0
# 2                    0.089686             -0.025899            7.0
# 3                    0.031390             -0.025899            7.0
# 4                    0.058296             -0.025899           11.0
#
#    time_to_solve_mean  prior_assessment_frequency  \
# 0            7.833333                           0
# 1            7.833333                           0
# 2            7.833333                           0
# 3            7.833333                           0
# 4            7.833333                           0
#
#    prior_KnowledgeTag_frequency  prior_testTag_frequency
# 0                             0                        0
# 1                             0                        1
# 2                             1                        2
# 3                             2                        3
# 4                             3                        4
#
# [5 rows x 27 columns]

# %% [markdown]
# ## 3. Train/Test 데이터 셋 분리

# %%
# train과 test 데이터셋은 사용자 별로 묶어서 분리를 해주어야함
random.seed(42)

def custom_train_test_split(df, ratio=0.7, split=True):
    # df: 입력 데이터프레임
    # ratio: 학습 데이터의 비율, 기본값은 0.7
    # split: True로 설정할 경우 테스트 데이터를 반환, False로 설정할 경우 학습 데이터를 반환

    # 사용자(UserID) 아이디와 해당 유저의 데이터 개수를 튜플로 묶어 리스트로 만듭니다.
    users = list(zip(df['userID'].value_counts().index, df['userID'].value_counts()))
    
    # 유저 리스트를 무작위로 shuffle
    random.shuffle(users)

    # 학습용 데이터의 최대 길이를 계산(ratio), 1586610.2
    max_train_data_len = ratio*len(df) 

    # 학습용 데이터의 누적 개수와 학습에 사용할 유저 아이디를 저장할 변수 초기화
    sum_of_train_data = 0   # 1586711

    # 학습에 사용할 user_id 를 리스트에 추가
    user_ids =[]            # 4669 유저
    for user_id, count in users:
        sum_of_train_data += count
        if max_train_data_len < sum_of_train_data: # 학습 데이터의 누적 개수가 최대 길이를 초과하면 루프를 종료
            break
        user_ids.append(user_id) 

    # 학습용 데이터로 사용할 user_id 에 해당하는 데이터를 선택하여 train에 할당 합니다.
    train = df[df['userID'].isin(user_ids)]

    # 테스트 데이터로 사용할 user_id 에 해당하는 데이터를 선택하여 test에 할당합니다.
    test = df[df['userID'].isin(user_ids) == False]
    
    # test 데이터셋은 각 유저의 마지막 interaction만 추출
    test = test[test['userID'] != test['userID'].shift(-1)]
    return train, test

# %%
train, test = custom_train_test_split(df)

# %%
df.columns.tolist()
# Out:
# ['userID',
#  'assessmentItemID',
#  'testId',
#  'answerCode',
#  'Timestamp',
#  'KnowledgeTag',
#  'testTag',
#  'user_correct_answer',
#  'user_total_answer',
#  'user_acc',
#  'user_sum',
#  'user_mean',
#  'assessment_sum',
#  'assessment_mean',
#  'test_sum',
#  'test_mean',
#  'knowledgeTag_sum',
#  'knowledgeTag_mean',
#  'testTag_sum',
#  'testTag_mean',
#  'relative_answer_assessment',
#  'relative_answer_mean',
#  'time_to_solve',
#  'time_to_solve_mean',
#  'prior_assessment_frequency',
#  'prior_KnowledgeTag_frequency',
#  'prior_testTag_frequency']

# %% [markdown]
# ## 4. Feature Selection

# %%
# 피쳐 13개 

FEATS = [
 'KnowledgeTag',
 'testTag',
 'user_correct_answer',
 'user_total_answer',
 'user_acc',
#  'user_sum',
 'user_mean',
#  'assessment_sum',
 'assessment_mean',
#  'test_sum',
 'test_mean',
#  'knowledgeTag_sum',
 'knowledgeTag_mean',
#  'testTag_sum',
#  'testTag_mean',
 #'relative_answer_assessment',
 'relative_answer_mean',
 'time_to_solve', 
 'time_to_solve_mean',
#  'prior_assessment_frequency',
#  'prior_KnowledgeTag_frequency',
 'prior_testTag_frequency'
 ]

# %%
# X, y 값 분리 피쳐들, answerCode
y_train = train['answerCode']
train = train.drop(['answerCode'], axis=1)

y_test = test['answerCode']
test = test.drop(['answerCode'], axis=1)

# 훈련 데이터와 테스트 데이터를 나누는 부분
X_train = train[FEATS]
X_test = test[FEATS]

# XGBoost 데이터 형태로 변환
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# %% [markdown]
# ## 4. 훈련 및 검증

# %%
# XGBoost 모델 파라미터 설정
params = {
    'objective': 'binary:logistic',  # 이진 분류 문제
    'eval_metric': 'auc',            # 평가 지표
    'max_depth': 6,                  # 트리의 최대 깊이
    'eta': 0.1,                      # 학습률
    'subsample': 0.8,                # 훈련 데이터 샘플링 비율
    'colsample_bytree': 0.8,         # 각 트리마다 사용되는 특성의 비율
    'min_child_weight': 1,           # 리프 노드의 최소 가중치 합
    'gamma': 0.1                     # 리프 노드의 가중치를 더할지 결정하는 파라미터
}

# XGBoost 모델 훈련
num_round = 500  # 훈련 라운드 수
bst = xgb.train(params, dtrain, num_round, [(dtrain, 'train'), (dtest, 'test')])

# 테스트 데이터에 대한 예측
preds = bst.predict(dtest)

# 정확도 및 AUC 평가
acc = accuracy_score(y_test, np.where(preds >= 0.5, 1, 0))
auc = roc_auc_score(y_test, preds)

print(f'VALID AUC: {auc} ACC: {acc}\n')
# Out:
# /Users/daeheehan/anaconda3/envs/dkt/lib/python3.10/site-packages/xgboost/core.py:727: FutureWarning: Pass `evals` as keyword args.
#   warnings.warn(msg, FutureWarning)
# [0]	train-auc:0.81994	test-auc:0.77861
# [1]	train-auc:0.82919	test-auc:0.79273
# [2]	train-auc:0.82778	test-auc:0.78982
# [3]	train-auc:0.83017	test-auc:0.79544
# [4]	train-auc:0.82814	test-auc:0.79216
# [5]	train-auc:0.83035	test-auc:0.79559
# [6]	train-auc:0.83155	test-auc:0.79686
# [7]	train-auc:0.83252	test-auc:0.79782
# [8]	train-auc:0.83324	test-auc:0.79879
# [9]	train-auc:0.83316	test-auc:0.79767
# [10]	train-auc:0.83379	test-auc:0.79811
# [11]	train-auc:0.83357	test-auc:0.79751
# [12]	train-auc:0.83422	test-auc:0.79834
# [13]	train-auc:0.83414	test-auc:0.79784
# [14]	train-auc:0.83396	test-auc:0.79747
# [15]	train-auc:0.83484	test-auc:0.79902
# [16]	train-auc:0.83544	test-auc:0.79939
# [17]	train-auc:0.83596	test-auc:0.80061
# [18]	train-auc:0.83655	test-auc:0.80154
# [19]	train-auc:0.83685	test-auc:0.80217
# [20]	train-auc:0.83712	test-auc:0.80276
# [21]	train-auc:0.83738	test-auc:0.80335
# [22]	train-auc:0.83766	test-auc:0.80354
# [23]	train-auc:0.83790	test-auc:0.80412
# [24]	train-auc:0.83820	test-auc:0.80438
# [25]	train-auc:0.83845	test-auc:0.80448
# [26]	train-auc:0.83874	test-auc:0.80460
# [27]	train-auc:0.83894	test-auc:0.80483
# [28]	train-auc:0.83916	test-auc:0.80549
# [29]	train-auc:0.83930	test-auc:0.80558
# [30]	train-auc:0.83948	test-auc:0.80575
# [31]	train-auc:0.83965	test-auc:0.80592
# [32]	train-auc:0.83985	test-auc:0.80625
# [33]	train-auc:0.83999	test-auc:0.80622
# [34]	train-auc:0.84014	test-auc:0.80597
# [35]	train-auc:0.84032	test-auc:0.80618
# [36]	train-auc:0.84043	test-auc:0.80621
# [37]	train-auc:0.84053	test-auc:0.80621
# [38]	train-auc:0.84067	test-auc:0.80629
# [39]	train-auc:0.84084	test-auc:0.80634
# [40]	train-auc:0.84096	test-auc:0.80636
# [41]	train-auc:0.84107	test-auc:0.80661
# [42]	train-auc:0.84123	test-auc:0.80687
# [43]	train-auc:0.84135	test-auc:0.80706
# [44]	train-auc:0.84143	test-auc:0.80713
# [45]	train-auc:0.84154	test-auc:0.80703
# [46]	train-auc:0.84164	test-auc:0.80723
# [47]	train-auc:0.84177	test-auc:0.80736
# [48]	train-auc:0.84185	test-auc:0.80746
# [49]	train-auc:0.84201	test-auc:0.80742
# [50]	train-auc:0.84214	test-auc:0.80766
# [51]	train-auc:0.84222	test-auc:0.80771
# [52]	train-auc:0.84234	test-auc:0.80784
# [53]	train-auc:0.84245	test-auc:0.80798
# [54]	train-auc:0.84249	test-auc:0.80803
# [55]	train-auc:0.84258	test-auc:0.80817
# [56]	train-auc:0.84267	test-auc:0.80820
# [57]	train-auc:0.84277	test-auc:0.80841
# [58]	train-auc:0.84291	test-auc:0.80844
# [59]	train-auc:0.84302	test-auc:0.80864
# [60]	train-auc:0.84312	test-auc:0.80874
# [61]	train-auc:0.84318	test-auc:0.80877
# [62]	train-auc:0.84323	test-auc:0.80877
# [63]	train-auc:0.84332	test-auc:0.80879
# [64]	train-auc:0.84337	test-auc:0.80882
# [65]	train-auc:0.84341	test-auc:0.80887
# [66]	train-auc:0.84351	test-auc:0.80889
# [67]	train-auc:0.84356	test-auc:0.80892
# [68]	train-auc:0.84365	test-auc:0.80910
# [69]	train-auc:0.84371	test-auc:0.80904
# [70]	train-auc:0.84382	test-auc:0.80902
# [71]	train-auc:0.84387	test-auc:0.80911
# [72]	train-auc:0.84395	test-auc:0.80920
# [73]	train-auc:0.84400	test-auc:0.80932
# [74]	train-auc:0.84409	test-auc:0.80935
# [75]	train-auc:0.84414	test-auc:0.80934
# [76]	train-auc:0.84419	test-auc:0.80936
# [77]	train-auc:0.84424	test-auc:0.80931
# [78]	train-auc:0.84432	test-auc:0.80938
# [79]	train-auc:0.84439	test-auc:0.80939
# [80]	train-auc:0.84450	test-auc:0.80942
# [81]	train-auc:0.84454	test-auc:0.80946
# [82]	train-auc:0.84459	test-auc:0.80950
# [83]	train-auc:0.84465	test-auc:0.80966
# [84]	train-auc:0.84467	test-auc:0.80969
# [85]	train-auc:0.84472	test-auc:0.80978
# [86]	train-auc:0.84476	test-auc:0.80988
# [87]	train-auc:0.84481	test-auc:0.80987
# [88]	train-auc:0.84488	test-auc:0.80994
# [89]	train-auc:0.84494	test-auc:0.80996
# [90]	train-auc:0.84498	test-auc:0.81000
# [91]	train-auc:0.84504	test-auc:0.80996
# [92]	train-auc:0.84505	test-auc:0.81001
# [93]	train-auc:0.84511	test-auc:0.80995
# [94]	train-auc:0.84518	test-auc:0.81002
# [95]	train-auc:0.84521	test-auc:0.81005
# [96]	train-auc:0.84524	test-auc:0.81004
# [97]	train-auc:0.84535	test-auc:0.81017
# [98]	train-auc:0.84540	test-auc:0.81016
# [99]	train-auc:0.84542	test-auc:0.81020
# [100]	train-auc:0.84549	test-auc:0.81021
# [101]	train-auc:0.84551	test-auc:0.81025
# [102]	train-auc:0.84556	test-auc:0.81017
# [103]	train-auc:0.84561	test-auc:0.81014
# [104]	train-auc:0.84563	test-auc:0.81019
# [105]	train-auc:0.84569	test-auc:0.81037
# [106]	train-auc:0.84574	test-auc:0.81042
# [107]	train-auc:0.84580	test-auc:0.81049
# [108]	train-auc:0.84586	test-auc:0.81045
# [109]	train-auc:0.84590	test-auc:0.81038
# [110]	train-auc:0.84592	test-auc:0.81043
# [111]	train-auc:0.84599	test-auc:0.81055
# [112]	train-auc:0.84602	test-auc:0.81053
# [113]	train-auc:0.84607	test-auc:0.81049
# [114]	train-auc:0.84612	test-auc:0.81045
# [115]	train-auc:0.84617	test-auc:0.81044
# [116]	train-auc:0.84623	test-auc:0.81046
# [117]	train-auc:0.84628	test-auc:0.81045
# [118]	train-auc:0.84631	test-auc:0.81052
# [119]	train-auc:0.84634	test-auc:0.81054
# [120]	train-auc:0.84636	test-auc:0.81054
# [121]	train-auc:0.84643	test-auc:0.81036
# [122]	train-auc:0.84646	test-auc:0.81034
# [123]	train-auc:0.84648	test-auc:0.81040
# [124]	train-auc:0.84651	test-auc:0.81046
# [125]	train-auc:0.84653	test-auc:0.81047
# [126]	train-auc:0.84657	test-auc:0.81048
# [127]	train-auc:0.84666	test-auc:0.81045
# [128]	train-auc:0.84671	test-auc:0.81045
# [129]	train-auc:0.84673	test-auc:0.81047
# [130]	train-auc:0.84675	test-auc:0.81047
# [131]	train-auc:0.84681	test-auc:0.81040
# [132]	train-auc:0.84683	test-auc:0.81043
# [133]	train-auc:0.84685	test-auc:0.81045
# [134]	train-auc:0.84690	test-auc:0.81043
# [135]	train-auc:0.84697	test-auc:0.81062
# [136]	train-auc:0.84703	test-auc:0.81067
# [137]	train-auc:0.84710	test-auc:0.81078
# [138]	train-auc:0.84712	test-auc:0.81076
# [139]	train-auc:0.84714	test-auc:0.81076
# [140]	train-auc:0.84718	test-auc:0.81071
# [141]	train-auc:0.84723	test-auc:0.81072
# [142]	train-auc:0.84733	test-auc:0.81078
# [143]	train-auc:0.84736	test-auc:0.81092
# [144]	train-auc:0.84742	test-auc:0.81106
# [145]	train-auc:0.84746	test-auc:0.81112
# [146]	train-auc:0.84750	test-auc:0.81116
# [147]	train-auc:0.84753	test-auc:0.81126
# [148]	train-auc:0.84755	test-auc:0.81132
# [149]	train-auc:0.84760	test-auc:0.81116
# [150]	train-auc:0.84763	test-auc:0.81115
# [151]	train-auc:0.84766	test-auc:0.81113
# [152]	train-auc:0.84770	test-auc:0.81102
# [153]	train-auc:0.84772	test-auc:0.81102
# [154]	train-auc:0.84775	test-auc:0.81105
# [155]	train-auc:0.84777	test-auc:0.81105
# [156]	train-auc:0.84780	test-auc:0.81102
# [157]	train-auc:0.84785	test-auc:0.81103
# [158]	train-auc:0.84786	test-auc:0.81103
# [159]	train-auc:0.84788	test-auc:0.81095
# [160]	train-auc:0.84790	test-auc:0.81096
# [161]	train-auc:0.84795	test-auc:0.81104
# [162]	train-auc:0.84797	test-auc:0.81107
# [163]	train-auc:0.84800	test-auc:0.81107
# [164]	train-auc:0.84803	test-auc:0.81102
# [165]	train-auc:0.84807	test-auc:0.81099
# [166]	train-auc:0.84810	test-auc:0.81093
# [167]	train-auc:0.84813	test-auc:0.81101
# [168]	train-auc:0.84819	test-auc:0.81101
# [169]	train-auc:0.84824	test-auc:0.81099
# [170]	train-auc:0.84828	test-auc:0.81098
# [171]	train-auc:0.84832	test-auc:0.81093
# [172]	train-auc:0.84839	test-auc:0.81107
# [173]	train-auc:0.84842	test-auc:0.81112
# [174]	train-auc:0.84847	test-auc:0.81112
# [175]	train-auc:0.84851	test-auc:0.81099
# [176]	train-auc:0.84853	test-auc:0.81099
# [177]	train-auc:0.84859	test-auc:0.81113
# [178]	train-auc:0.84863	test-auc:0.81111
# [179]	train-auc:0.84867	test-auc:0.81112
# [180]	train-auc:0.84874	test-auc:0.81115
# [181]	train-auc:0.84880	test-auc:0.81132
# [182]	train-auc:0.84882	test-auc:0.81130
# [183]	train-auc:0.84886	test-auc:0.81131
# [184]	train-auc:0.84892	test-auc:0.81137
# [185]	train-auc:0.84895	test-auc:0.81138
# [186]	train-auc:0.84897	test-auc:0.81134
# [187]	train-auc:0.84901	test-auc:0.81143
# [188]	train-auc:0.84903	test-auc:0.81140
# [189]	train-auc:0.84907	test-auc:0.81139
# [190]	train-auc:0.84911	test-auc:0.81147
# [191]	train-auc:0.84914	test-auc:0.81159
# [192]	train-auc:0.84917	test-auc:0.81155
# [193]	train-auc:0.84920	test-auc:0.81161
# [194]	train-auc:0.84924	test-auc:0.81162
# [195]	train-auc:0.84927	test-auc:0.81157
# [196]	train-auc:0.84930	test-auc:0.81158
# [197]	train-auc:0.84934	test-auc:0.81153
# [198]	train-auc:0.84936	test-auc:0.81142
# [199]	train-auc:0.84942	test-auc:0.81154
# [200]	train-auc:0.84945	test-auc:0.81153
# [201]	train-auc:0.84952	test-auc:0.81161
# [202]	train-auc:0.84957	test-auc:0.81165
# [203]	train-auc:0.84959	test-auc:0.81156
# [204]	train-auc:0.84962	test-auc:0.81154
# [205]	train-auc:0.84964	test-auc:0.81145
# [206]	train-auc:0.84967	test-auc:0.81143
# [207]	train-auc:0.84969	test-auc:0.81138
# [208]	train-auc:0.84974	test-auc:0.81139
# [209]	train-auc:0.84977	test-auc:0.81135
# [210]	train-auc:0.84981	test-auc:0.81137
# [211]	train-auc:0.84984	test-auc:0.81137
# [212]	train-auc:0.84989	test-auc:0.81134
# [213]	train-auc:0.84992	test-auc:0.81134
# [214]	train-auc:0.84995	test-auc:0.81140
# [215]	train-auc:0.84999	test-auc:0.81136
# [216]	train-auc:0.85000	test-auc:0.81137
# [217]	train-auc:0.85003	test-auc:0.81137
# [218]	train-auc:0.85005	test-auc:0.81132
# [219]	train-auc:0.85008	test-auc:0.81140
# [220]	train-auc:0.85010	test-auc:0.81146
# [221]	train-auc:0.85013	test-auc:0.81144
# [222]	train-auc:0.85016	test-auc:0.81147
# [223]	train-auc:0.85022	test-auc:0.81148
# [224]	train-auc:0.85026	test-auc:0.81158
# [225]	train-auc:0.85027	test-auc:0.81162
# [226]	train-auc:0.85030	test-auc:0.81161
# [227]	train-auc:0.85032	test-auc:0.81160
# [228]	train-auc:0.85035	test-auc:0.81157
# [229]	train-auc:0.85037	test-auc:0.81154
# [230]	train-auc:0.85041	test-auc:0.81157
# [231]	train-auc:0.85043	test-auc:0.81161
# [232]	train-auc:0.85047	test-auc:0.81158
# [233]	train-auc:0.85048	test-auc:0.81157
# [234]	train-auc:0.85052	test-auc:0.81155
# [235]	train-auc:0.85056	test-auc:0.81155
# [236]	train-auc:0.85057	test-auc:0.81153
# [237]	train-auc:0.85060	test-auc:0.81149
# [238]	train-auc:0.85064	test-auc:0.81148
# [239]	train-auc:0.85066	test-auc:0.81147
# [240]	train-auc:0.85069	test-auc:0.81148
# [241]	train-auc:0.85072	test-auc:0.81151
# [242]	train-auc:0.85076	test-auc:0.81153
# [243]	train-auc:0.85079	test-auc:0.81152
# [244]	train-auc:0.85081	test-auc:0.81147
# [245]	train-auc:0.85083	test-auc:0.81149
# [246]	train-auc:0.85085	test-auc:0.81148
# [247]	train-auc:0.85088	test-auc:0.81147
# [248]	train-auc:0.85092	test-auc:0.81153
# [249]	train-auc:0.85095	test-auc:0.81157
# [250]	train-auc:0.85099	test-auc:0.81160
# [251]	train-auc:0.85101	test-auc:0.81162
# [252]	train-auc:0.85102	test-auc:0.81162
# [253]	train-auc:0.85105	test-auc:0.81164
# [254]	train-auc:0.85107	test-auc:0.81165
# [255]	train-auc:0.85109	test-auc:0.81164
# [256]	train-auc:0.85113	test-auc:0.81162
# [257]	train-auc:0.85115	test-auc:0.81162
# [258]	train-auc:0.85118	test-auc:0.81159
# [259]	train-auc:0.85120	test-auc:0.81162
# [260]	train-auc:0.85121	test-auc:0.81172
# [261]	train-auc:0.85123	test-auc:0.81174
# [262]	train-auc:0.85127	test-auc:0.81189
# [263]	train-auc:0.85131	test-auc:0.81197
# [264]	train-auc:0.85134	test-auc:0.81200
# [265]	train-auc:0.85138	test-auc:0.81198
# [266]	train-auc:0.85139	test-auc:0.81190
# [267]	train-auc:0.85144	test-auc:0.81183
# [268]	train-auc:0.85147	test-auc:0.81178
# [269]	train-auc:0.85150	test-auc:0.81168
# [270]	train-auc:0.85153	test-auc:0.81177
# [271]	train-auc:0.85154	test-auc:0.81181
# [272]	train-auc:0.85157	test-auc:0.81177
# [273]	train-auc:0.85159	test-auc:0.81179
# [274]	train-auc:0.85163	test-auc:0.81190
# [275]	train-auc:0.85167	test-auc:0.81192
# [276]	train-auc:0.85169	test-auc:0.81193
# [277]	train-auc:0.85171	test-auc:0.81192
# [278]	train-auc:0.85173	test-auc:0.81196
# [279]	train-auc:0.85176	test-auc:0.81200
# [280]	train-auc:0.85177	test-auc:0.81203
# [281]	train-auc:0.85182	test-auc:0.81219
# [282]	train-auc:0.85185	test-auc:0.81221
# [283]	train-auc:0.85187	test-auc:0.81224
# [284]	train-auc:0.85190	test-auc:0.81232
# [285]	train-auc:0.85191	test-auc:0.81232
# [286]	train-auc:0.85194	test-auc:0.81238
# [287]	train-auc:0.85196	test-auc:0.81243
# [288]	train-auc:0.85200	test-auc:0.81254
# [289]	train-auc:0.85205	test-auc:0.81249
# [290]	train-auc:0.85207	test-auc:0.81251
# [291]	train-auc:0.85209	test-auc:0.81244
# [292]	train-auc:0.85213	test-auc:0.81240
# [293]	train-auc:0.85215	test-auc:0.81235
# [294]	train-auc:0.85219	test-auc:0.81243
# [295]	train-auc:0.85221	test-auc:0.81242
# [296]	train-auc:0.85224	test-auc:0.81242
# [297]	train-auc:0.85226	test-auc:0.81246
# [298]	train-auc:0.85228	test-auc:0.81246
# [299]	train-auc:0.85231	test-auc:0.81245
# [300]	train-auc:0.85234	test-auc:0.81249
# [301]	train-auc:0.85236	test-auc:0.81249
# [302]	train-auc:0.85237	test-auc:0.81247
# [303]	train-auc:0.85241	test-auc:0.81255
# [304]	train-auc:0.85241	test-auc:0.81257
# [305]	train-auc:0.85243	test-auc:0.81257
# [306]	train-auc:0.85245	test-auc:0.81256
# [307]	train-auc:0.85247	test-auc:0.81262
# [308]	train-auc:0.85250	test-auc:0.81255
# [309]	train-auc:0.85253	test-auc:0.81250
# [310]	train-auc:0.85255	test-auc:0.81255
# [311]	train-auc:0.85259	test-auc:0.81266
# [312]	train-auc:0.85262	test-auc:0.81262
# [313]	train-auc:0.85263	test-auc:0.81272
# [314]	train-auc:0.85265	test-auc:0.81272
# [315]	train-auc:0.85268	test-auc:0.81274
# [316]	train-auc:0.85270	test-auc:0.81276
# [317]	train-auc:0.85273	test-auc:0.81279
# [318]	train-auc:0.85276	test-auc:0.81281
# [319]	train-auc:0.85280	test-auc:0.81285
# [320]	train-auc:0.85284	test-auc:0.81278
# [321]	train-auc:0.85286	test-auc:0.81270
# [322]	train-auc:0.85288	test-auc:0.81279
# [323]	train-auc:0.85291	test-auc:0.81282
# [324]	train-auc:0.85293	test-auc:0.81280
# [325]	train-auc:0.85296	test-auc:0.81279
# [326]	train-auc:0.85298	test-auc:0.81271
# [327]	train-auc:0.85301	test-auc:0.81272
# [328]	train-auc:0.85303	test-auc:0.81272
# [329]	train-auc:0.85305	test-auc:0.81280
# [330]	train-auc:0.85309	test-auc:0.81275
# [331]	train-auc:0.85311	test-auc:0.81276
# [332]	train-auc:0.85313	test-auc:0.81273
# [333]	train-auc:0.85315	test-auc:0.81281
# [334]	train-auc:0.85317	test-auc:0.81283
# [335]	train-auc:0.85320	test-auc:0.81286
# [336]	train-auc:0.85322	test-auc:0.81284
# [337]	train-auc:0.85325	test-auc:0.81287
# [338]	train-auc:0.85327	test-auc:0.81290
# [339]	train-auc:0.85330	test-auc:0.81289
# [340]	train-auc:0.85332	test-auc:0.81289
# [341]	train-auc:0.85334	test-auc:0.81294
# [342]	train-auc:0.85335	test-auc:0.81300
# [343]	train-auc:0.85337	test-auc:0.81301
# [344]	train-auc:0.85340	test-auc:0.81302
# [345]	train-auc:0.85341	test-auc:0.81304
# [346]	train-auc:0.85344	test-auc:0.81303
# [347]	train-auc:0.85345	test-auc:0.81298
# [348]	train-auc:0.85349	test-auc:0.81297
# [349]	train-auc:0.85351	test-auc:0.81288
# [350]	train-auc:0.85353	test-auc:0.81295
# [351]	train-auc:0.85357	test-auc:0.81299
# [352]	train-auc:0.85360	test-auc:0.81315
# [353]	train-auc:0.85362	test-auc:0.81319
# [354]	train-auc:0.85364	test-auc:0.81324
# [355]	train-auc:0.85366	test-auc:0.81321
# [356]	train-auc:0.85371	test-auc:0.81323
# [357]	train-auc:0.85373	test-auc:0.81318
# [358]	train-auc:0.85375	test-auc:0.81312
# [359]	train-auc:0.85378	test-auc:0.81316
# [360]	train-auc:0.85381	test-auc:0.81323
# [361]	train-auc:0.85383	test-auc:0.81323
# [362]	train-auc:0.85385	test-auc:0.81330
# [363]	train-auc:0.85388	test-auc:0.81329
# [364]	train-auc:0.85390	test-auc:0.81321
# [365]	train-auc:0.85392	test-auc:0.81324
# [366]	train-auc:0.85395	test-auc:0.81320
# [367]	train-auc:0.85397	test-auc:0.81315
# [368]	train-auc:0.85399	test-auc:0.81317
# [369]	train-auc:0.85401	test-auc:0.81317
# [370]	train-auc:0.85404	test-auc:0.81330
# [371]	train-auc:0.85405	test-auc:0.81326
# [372]	train-auc:0.85407	test-auc:0.81331
# [373]	train-auc:0.85408	test-auc:0.81335
# [374]	train-auc:0.85410	test-auc:0.81334
# [375]	train-auc:0.85411	test-auc:0.81332
# [376]	train-auc:0.85414	test-auc:0.81326
# [377]	train-auc:0.85416	test-auc:0.81326
# [378]	train-auc:0.85419	test-auc:0.81331
# [379]	train-auc:0.85422	test-auc:0.81332
# [380]	train-auc:0.85423	test-auc:0.81331
# [381]	train-auc:0.85424	test-auc:0.81332
# [382]	train-auc:0.85427	test-auc:0.81335
# [383]	train-auc:0.85428	test-auc:0.81337
# [384]	train-auc:0.85432	test-auc:0.81332
# [385]	train-auc:0.85434	test-auc:0.81332
# [386]	train-auc:0.85438	test-auc:0.81328
# [387]	train-auc:0.85440	test-auc:0.81323
# [388]	train-auc:0.85444	test-auc:0.81331
# [389]	train-auc:0.85446	test-auc:0.81335
# [390]	train-auc:0.85449	test-auc:0.81328
# [391]	train-auc:0.85451	test-auc:0.81331
# [392]	train-auc:0.85454	test-auc:0.81329
# [393]	train-auc:0.85456	test-auc:0.81333
# [394]	train-auc:0.85458	test-auc:0.81329
# [395]	train-auc:0.85462	test-auc:0.81336
# [396]	train-auc:0.85464	test-auc:0.81344
# [397]	train-auc:0.85466	test-auc:0.81342
# [398]	train-auc:0.85467	test-auc:0.81350
# [399]	train-auc:0.85470	test-auc:0.81346
# [400]	train-auc:0.85473	test-auc:0.81350
# [401]	train-auc:0.85476	test-auc:0.81350
# [402]	train-auc:0.85479	test-auc:0.81351
# [403]	train-auc:0.85480	test-auc:0.81350
# [404]	train-auc:0.85483	test-auc:0.81361
# [405]	train-auc:0.85485	test-auc:0.81362
# [406]	train-auc:0.85487	test-auc:0.81356
# [407]	train-auc:0.85489	test-auc:0.81352
# [408]	train-auc:0.85490	test-auc:0.81349
# [409]	train-auc:0.85492	test-auc:0.81346
# [410]	train-auc:0.85494	test-auc:0.81346
# [411]	train-auc:0.85496	test-auc:0.81344
# [412]	train-auc:0.85499	test-auc:0.81345
# [413]	train-auc:0.85501	test-auc:0.81346
# [414]	train-auc:0.85504	test-auc:0.81348
# [415]	train-auc:0.85506	test-auc:0.81340
# [416]	train-auc:0.85508	test-auc:0.81342
# [417]	train-auc:0.85511	test-auc:0.81343
# [418]	train-auc:0.85513	test-auc:0.81349
# [419]	train-auc:0.85516	test-auc:0.81356
# [420]	train-auc:0.85519	test-auc:0.81358
# [421]	train-auc:0.85522	test-auc:0.81355
# [422]	train-auc:0.85524	test-auc:0.81354
# [423]	train-auc:0.85526	test-auc:0.81359
# [424]	train-auc:0.85527	test-auc:0.81358
# [425]	train-auc:0.85529	test-auc:0.81360
# [426]	train-auc:0.85531	test-auc:0.81363
# [427]	train-auc:0.85535	test-auc:0.81363
# [428]	train-auc:0.85537	test-auc:0.81360
# [429]	train-auc:0.85539	test-auc:0.81355
# [430]	train-auc:0.85541	test-auc:0.81359
# [431]	train-auc:0.85542	test-auc:0.81357
# [432]	train-auc:0.85546	test-auc:0.81355
# [433]	train-auc:0.85547	test-auc:0.81355
# [434]	train-auc:0.85549	test-auc:0.81356
# [435]	train-auc:0.85551	test-auc:0.81355
# [436]	train-auc:0.85552	test-auc:0.81351
# [437]	train-auc:0.85554	test-auc:0.81347
# [438]	train-auc:0.85557	test-auc:0.81351
# [439]	train-auc:0.85559	test-auc:0.81357
# [440]	train-auc:0.85560	test-auc:0.81354
# [441]	train-auc:0.85562	test-auc:0.81360
# [442]	train-auc:0.85564	test-auc:0.81366
# [443]	train-auc:0.85565	test-auc:0.81363
# [444]	train-auc:0.85568	test-auc:0.81355
# [445]	train-auc:0.85570	test-auc:0.81353
# [446]	train-auc:0.85573	test-auc:0.81355
# [447]	train-auc:0.85576	test-auc:0.81353
# [448]	train-auc:0.85580	test-auc:0.81355
# [449]	train-auc:0.85582	test-auc:0.81351
# [450]	train-auc:0.85583	test-auc:0.81344
# [451]	train-auc:0.85585	test-auc:0.81345
# [452]	train-auc:0.85588	test-auc:0.81345
# [453]	train-auc:0.85590	test-auc:0.81347
# [454]	train-auc:0.85593	test-auc:0.81357
# [455]	train-auc:0.85595	test-auc:0.81360
# [456]	train-auc:0.85597	test-auc:0.81362
# [457]	train-auc:0.85603	test-auc:0.81366
# [458]	train-auc:0.85604	test-auc:0.81366
# [459]	train-auc:0.85606	test-auc:0.81369
# [460]	train-auc:0.85608	test-auc:0.81373
# [461]	train-auc:0.85610	test-auc:0.81371
# [462]	train-auc:0.85612	test-auc:0.81371
# [463]	train-auc:0.85613	test-auc:0.81376
# [464]	train-auc:0.85616	test-auc:0.81380
# [465]	train-auc:0.85618	test-auc:0.81374
# [466]	train-auc:0.85620	test-auc:0.81372
# [467]	train-auc:0.85623	test-auc:0.81375
# [468]	train-auc:0.85624	test-auc:0.81373
# [469]	train-auc:0.85627	test-auc:0.81376
# [470]	train-auc:0.85629	test-auc:0.81373
# [471]	train-auc:0.85632	test-auc:0.81373
# [472]	train-auc:0.85633	test-auc:0.81372
# [473]	train-auc:0.85635	test-auc:0.81373
# [474]	train-auc:0.85637	test-auc:0.81374
# [475]	train-auc:0.85640	test-auc:0.81384
# [476]	train-auc:0.85645	test-auc:0.81376
# [477]	train-auc:0.85647	test-auc:0.81374
# [478]	train-auc:0.85649	test-auc:0.81371
# [479]	train-auc:0.85651	test-auc:0.81369
# [480]	train-auc:0.85654	test-auc:0.81366
# [481]	train-auc:0.85657	test-auc:0.81373
# [482]	train-auc:0.85659	test-auc:0.81373
# [483]	train-auc:0.85660	test-auc:0.81372
# [484]	train-auc:0.85662	test-auc:0.81372
# [485]	train-auc:0.85664	test-auc:0.81377
# [486]	train-auc:0.85668	test-auc:0.81397
# [487]	train-auc:0.85670	test-auc:0.81398
# [488]	train-auc:0.85671	test-auc:0.81398
# [489]	train-auc:0.85673	test-auc:0.81400
# [490]	train-auc:0.85675	test-auc:0.81404
# [491]	train-auc:0.85679	test-auc:0.81413
# [492]	train-auc:0.85682	test-auc:0.81420
# [493]	train-auc:0.85685	test-auc:0.81425
# [494]	train-auc:0.85687	test-auc:0.81419
# [495]	train-auc:0.85689	test-auc:0.81416
# [496]	train-auc:0.85691	test-auc:0.81411
# [497]	train-auc:0.85695	test-auc:0.81407
# [498]	train-auc:0.85696	test-auc:0.81408
# [499]	train-auc:0.85698	test-auc:0.81406
# VALID AUC: 0.8140618167362352 ACC: 0.7443946188340808

# %%
_ = xgb.plot_importance(bst)

# %% [markdown]
# ## 5. Inference

# %%
# LOAD TESTDATA
data_dir = './data/'
test_csv_file_path = os.path.join(data_dir, 'test_data.csv')
test_df = pd.read_csv(test_csv_file_path)

# FEATURE ENGINEERING
test_df = feature_engineering(test_df)

# LEAVE LAST INTERACTION ONLY
test_df = test_df[test_df['userID'] != test_df['userID'].shift(-1)]

# DROP ANSWERCODE
test_df = test_df.drop(['answerCode'], axis=1)

# 테스트 데이터에 대한 예측
total_preds = bst.predict(xgb.DMatrix(test_df[FEATS]))
# Out:
# /var/folders/8r/strv9f_x6b3ghnb0chcl145m0000gn/T/ipykernel_2741/21048499.py:63: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['time_to_solve'].fillna(method='ffill', inplace=True)

# %%
# 결과를 파일로 저장
output_dir = 'output_XGBoost/'
write_path = os.path.join(output_dir, "submission_XGBoost_f13.csv")
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
with open(write_path, 'w', encoding='utf8') as w:
    print("writing prediction: {}".format(write_path))
    w.write("id,prediction\n")
    for id, p in enumerate(total_preds):
        w.write('{},{}\n'.format(id, p))
# Out:
# writing prediction: output_XGBoost/submission_XGBoost_f13.csv
